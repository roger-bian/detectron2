# %%
import os
import json
import time
import datetime
import cv2
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import Visualizer
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Check training statistics

# %%
version = 'v1'
experiment_folder = f'_model/side_panel_screw/{version}'

def load_json_arr(json_path):
    lines = []
    with open(json_path, 'r') as f:
        for line in f:
            lines.append(json.loads(line))
    return lines

experiment_metrics = load_json_arr(experiment_folder + '/metrics.json')

# total loss
total_loss_x = [x['iteration'] for x in experiment_metrics if 'total_loss' in x]
total_loss_y = [x['total_loss'] for x in experiment_metrics if 'total_loss' in x]

# validation loss
validation_loss_x = [x['iteration'] for x in experiment_metrics if 'validation_loss' in x]
validation_loss_y = [x['validation_loss'] for x in experiment_metrics if 'validation_loss' in x]

# AP
segm_AP_x = [x['iteration'] for x in experiment_metrics if 'segm/AP' in x]
segm_AP_y = [x['segm/AP'] for x in experiment_metrics if 'segm/AP' in x]

# get best metrics
min_val_loss = 99999999
max_ap = 0
for idx, x in enumerate(experiment_metrics):
    if 'validation_loss' in x and x['validation_loss'] < min_val_loss:
        min_val_loss = x['validation_loss']
        i_val = x['iteration']
    
    if 'segm/AP' in x and x['segm/AP'] > max_ap:
        max_ap = x['segm/AP']
        i_ap = x['iteration']

# AP at best validation loss
segm_AP = segm_AP_y[segm_AP_x.index(i_val)]
# validation loss at best AP
val_loss = validation_loss_y[validation_loss_x.index(i_ap)]

# validation loss graph
print(f'Best validation loss: {min_val_loss}')
print(f'Best validation loss at best AP: {val_loss}')
plt.figure(figsize=(12, 5))
plt.plot(total_loss_x, total_loss_y)
plt.plot(validation_loss_x, validation_loss_y)
plt.scatter(i_val, min_val_loss, color='red', s=50)
plt.scatter(i_ap, val_loss, color='green', s=50)
plt.legend(['total_loss', 'validation_loss'], loc='upper right')
plt.xlim(left=0)
# plt.ylim(0, 0.6)
plt.grid()
plt.show()

# AP graph
print(f'Best segm/AP: {max_ap}')
print(f'Best segm/AP at best validation loss: {segm_AP}')
plt.figure(figsize=(12, 5))
plt.plot(segm_AP_x, segm_AP_y)
plt.scatter(i_val, segm_AP, color='red', s=50)
plt.scatter(i_ap, max_ap, color='green', s=50)
plt.legend(['AP'], loc='upper right')
plt.grid()
plt.show()
# Out:
# Best validation loss: 0.5140803070237894
# Best validation loss at best AP: 0.5140803070237894
# Best segm/AP: 69.72523953084975
# Best segm/AP at best validation loss: 69.72523953084975

# %% [markdown]
# # Inference on one image

# %%
PARENT_FOLDER = f'_model/side_panel_screw/{version}'
SELECTED_MODEL = 'model_best.pth'
IMAGE_PATH = "_data/side_panel_screw/coco/val_v1/JPEGImages/Pic_2026_04_02_144619_36.jpg"

CLASS_NAMES = [
    "screw"
]  # Add your class names here
CLASS_COLORS = [
    [255, 0, 0],  # Red for class 0
    # [0, 0, 255],  # Blue for class 1   # Uncomment if you have more classes
]

SCORE_THRESH = 0.8

# %%
# Function to configure the model for inference
def setup_inference(config_path, model_weights_path, score_thresh=0.3):
    cfg = get_cfg()
    cfg.set_new_allowed(True)
    cfg.merge_from_file(config_path)
    cfg.MODEL.WEIGHTS = os.path.join(model_weights_path)
    cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = score_thresh  # Minimum score to keep a detection
    cfg.MODEL.ROI_HEADS.NMS_THRESH_TEST = 0.5    # IoU threshold for NMS                                                                                                                                                                                                                                                                                                                                                                     
    return cfg

# Function to perform inference on a single image
def inference_on_image(image_path, predictor, metadata=None):
    img = cv2.imread(image_path)
    print(img.shape)
    outputs = predictor(img)
    instances = outputs["instances"].to("cpu")

    # Visualize results using visualizer
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=1)
    out = visualizer.draw_instance_predictions(instances)
    
    result_image = cv2.cvtColor(out.get_image(), cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(20, 20))
    plt.imshow(result_image)
    plt.show()

    # # Visualize by manual drawing on original image
    # for i in range(len(instances.pred_boxes)):
    #     coords = instances.pred_boxes.tensor[i].int().numpy()

    #     # draw boxes + write text
    #     draw_color = CLASS_COLORS[instances.pred_classes[i]]
    #     text = CLASS_NAMES[instances.pred_classes[i]]
        
    #     x_start = coords[0]
    #     y_start = coords[1]
    #     cv2.rectangle(img, (x_start, y_start), (coords[2], coords[3]), draw_color, 2)
        
    #     font = cv2.FONT_HERSHEY_SIMPLEX
    #     font_scale = .5
    #     font_thickness = 1
    #     text_size, _ = cv2.getTextSize(text, font, font_scale, font_thickness)
    #     text_w, text_h = text_size
    #     cv2.rectangle(img, (x_start, y_start), (x_start + text_w, y_start + text_h + 5), (255, 255, 255), -1)
    #     cv2.putText(img, text, (x_start, y_start + text_h), font, font_scale, draw_color, font_thickness, cv2.LINE_AA)

    # # plt.figure(figsize=(20, 20))
    # plt.imshow(img)
    # plt.show()

# Paths to your config file and trained model
config_path = f"{PARENT_FOLDER}/config.yaml"
model_weights_path = f"{PARENT_FOLDER}/{SELECTED_MODEL}"
image_path = IMAGE_PATH


# Set up the model for inference
cfg = setup_inference(config_path, model_weights_path, score_thresh=SCORE_THRESH)
predictor = DefaultPredictor(cfg)
    
# Perform inference
inference_on_image(image_path, predictor)

# %% [markdown]
# # Inference on directory of images & save to output folder

# %%
INPUT_FOLDER = "_data/side_panel/test"  # Folder containing input images
OUTPUT_FOLDER = "_data/side_panel/output"  # Folder to save output images

# Function to perform inference and save the results
def process_images_in_folder(input_folder, output_folder, predictor, metadata=None):
    os.makedirs(output_folder, exist_ok=True)
    output_subfolder = f"{output_folder}/{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
    os.makedirs(output_subfolder, exist_ok=True)
    
    for file_name in os.listdir(input_folder):
        file_path = os.path.join(input_folder, file_name)
        if os.path.isfile(file_path) and file_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
            img = cv2.imread(file_path)
            st = time.time()
            outputs = predictor(img)
            instances = outputs["instances"].to("cpu")
            
            visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=1)
            out = visualizer.draw_instance_predictions(instances)
            tt = time.time() - st
            print(tt)
            result_image = cv2.cvtColor(out.get_image(), cv2.COLOR_BGR2RGB)
            
            output_path = os.path.join(output_subfolder, f"result_{file_name}")
            cv2.imwrite(output_path, result_image)
            print(f"Saved result to {output_path}")

# Paths to your config file and trained model
config_path = f"{PARENT_FOLDER}/config.yaml"
model_weights_path = f"{PARENT_FOLDER}/{SELECTED_MODEL}"

# Set up the model for inference
cfg = setup_inference(config_path, model_weights_path, score_thresh=SCORE_THRESH)
predictor = DefaultPredictor(cfg)

# Process images in the input folder
process_images_in_folder(INPUT_FOLDER, OUTPUT_FOLDER, predictor)
# Out:
# 0.16137003898620605
# Saved result to _data/side_panel/output/20260326_144751/result_20260317_125930_silver_blended.bmp
# 0.19423770904541016
# Saved result to _data/side_panel/output/20260326_144751/result_20260318_153410_silver_blended.bmp
# 0.19932818412780762
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_154720_silver_blended.bmp
# 0.17646098136901855
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_120838_silver_blended.bmp
# 0.20479941368103027
# Saved result to _data/side_panel/output/20260326_144751/result_20260318_153531_silver_blended.bmp
# 0.17232322692871094
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_125317_silver_blended.bmp
# 0.16299653053283691
# Saved result to _data/side_panel/output/20260326_144751/result_20260317_125621_silver_blended.bmp
# 0.19044995307922363
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_120928_silver_blended.bmp
# 0.1589367389678955
# Saved result to _data/side_panel/output/20260326_144751/result_20260317_125709_silver_blended.bmp
# 0.1593940258026123
# Saved result to _data/side_panel/output/20260326_144751/result_20260317_125757_silver_blended.bmp
# 0.1856229305267334
# Saved result to _data/side_panel/output/20260326_144751/result_20260318_153246_silver_blended.bmp
# 0.17582273483276367
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_154945_silver_blended.bmp
# 0.18237829208374023
# Saved result to _data/side_panel/output/20260326_144751/result_20260318_153455_silver_blended.bmp
# 0.17126154899597168
# Saved result to _data/side_panel/output/20260326_144751/result_20260317_125844_silver_blended.bmp
# 0.19757080078125
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_154828_silver_blended.bmp
# 0.2131342887878418
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_125212_silver_blended.bmp
# 0.1649777889251709
# Saved result to _data/side_panel/output/20260326_144751/result_20260318_153332_silver_blended.bmp
# 0.17067337036132812
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_154902_silver_blended.bmp
# 0.16504859924316406
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_155035_silver_blended.bmp
# 0.1657428741455078
# Saved result to _data/side_panel/output/20260326_144751/result_20260319_121053_silver_blended.bmp
