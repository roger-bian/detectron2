# %% [markdown]
# # On One image

# %%
import os
import time
import cv2
from detectron2.config import get_cfg
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
import matplotlib.pyplot as plt

# %%
PARENT_FOLDER = "model/cap_glasses"

# %%
def set_metadata():
    # List of class names (labels) for your dataset
    class_names = ["cap", "glasses"]  

    # Define custom colors for each class (RGB values)
    thing_colors = [
        [255, 0, 0],    # Red for class 0 
        [0, 0, 255],    # Blue for class 1  
    ]

    # Create custom metadata for your dataset
    metadata = {
        "thing_classes": class_names,  # List of class names
        "thing_colors": thing_colors,  # List of colors for each class
    }

    # Register the metadata with the dataset name
    MetadataCatalog.get("face_accessories").set(**metadata)

# Function to configure the model for inference
def setup_inference(config_path, model_weights_path, score_thresh=0.3):
    cfg = get_cfg()
    cfg.set_new_allowed(True)
    cfg.merge_from_file(config_path)
    cfg.MODEL.WEIGHTS = os.path.join(model_weights_path)
    cfg.TEST.SCORE_THRESH = score_thresh  # Minimum score to keep a detection
    cfg.TEST.NMS_THRESH = 0.5    # IoU threshold for NMS                                                                                                                                                                                                                                                                                                                                                                     
    return cfg

# Function to perform inference on a single image
def inference_on_image(image_path, predictor, metadata=None, score_thresh=0.7):
    img = cv2.imread(image_path)
    outputs = predictor(img)
    instances = outputs["instances"]
    keep_indices = outputs["instances"].scores > score_thresh
    filtered_instances = instances[keep_indices]
    filtered_instances = filtered_instances.to('cpu')

    print(filtered_instances)
    
    # Visualize results using visualizer
    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=1)
    out = visualizer.draw_instance_predictions(filtered_instances)
    
    result_image = cv2.cvtColor(out.get_image(), cv2.COLOR_BGR2RGB)
    plt.imshow(result_image)
    plt.show()


    # Visualize by manual drawing on original image
    for i in range(len(filtered_instances.pred_boxes)):
        coords = filtered_instances.pred_boxes.tensor[i].int().numpy()

        # draw boxes + write text
        if filtered_instances.pred_classes[i] == 0:
            draw_color = (255, 0, 0)
            text = 'cap'
        else:
            draw_color = (0, 0, 255)
            text = 'glasses'
        
        x_start = coords[0]
        y_start = coords[1]
        cv2.rectangle(img, (x_start, y_start), (coords[2], coords[3]), draw_color, 2)
        
        font = cv2.FONT_HERSHEY_SIMPLEX
        font_scale = .5
        font_thickness = 1
        text_size, _ = cv2.getTextSize(text, font, font_scale, font_thickness)
        text_w, text_h = text_size
        cv2.rectangle(img, (x_start, y_start), (x_start + text_w, y_start + text_h + 5), (255, 255, 255), -1)
        cv2.putText(img, text, (x_start, y_start + text_h), font, font_scale, draw_color, font_thickness, cv2.LINE_AA)

    plt.imshow(img)
    plt.show()

# Paths to your config file and trained model
config_path = PARENT_FOLDER + "/config.yaml"
model_weights_path = PARENT_FOLDER + "/model_final.pth"
image_path = "../paloma/task18/training_data/v2/valid/11007.jpg"

# Set up the model for inference
cfg = setup_inference(config_path, model_weights_path)
predictor = DefaultPredictor(cfg)

# Load metadata (optional)
# metadata = MetadataCatalog.get(cfg.DATASETS.TEST[0])  # Replace with your dataset name
# Assuming you have registered your dataset (e.g., "laundry_train")
set_metadata()

metadata = MetadataCatalog.get("face_accessories")
# dataset_dicts = DatasetCatalog.get("laundry_train")
# Access the class names from the metadata
class_names = metadata.get("thing_classes", [])
# Print the class names with their corresponding indices
for idx, class_name in enumerate(class_names):
    print(f"Class {idx}: {class_name}")
    
# Perform inference
inference_on_image(image_path, predictor, metadata)
# Out:
# Class 0: cap
# Class 1: glasses
# c:\Users\roger\anaconda3\envs\detectron2\lib\site-packages\torch\functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3596.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Instances(num_instances=2, image_height=512, image_width=512, fields=[pred_boxes: Boxes(tensor([[ 92.4304,   0.0000, 510.5303, 206.6641],
#         [125.3173, 205.5339, 407.6177, 324.6357]])), scores: tensor([1.0000, 1.0000]), pred_classes: tensor([0, 1])])

# %% [markdown]
# # All image in a folder

# %%
# Function to perform inference and save the results
def process_images_in_folder(input_folder, output_folder, predictor, metadata):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for file_name in os.listdir(input_folder):
        file_path = os.path.join(input_folder, file_name)
        if os.path.isfile(file_path) and file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            img = cv2.imread(file_path)
            st = time.time()
            outputs = predictor(img)
            instances = outputs["instances"]
            keep_indices = outputs["instances"].scores > 0.3
            filtered_instances = instances[keep_indices]
            
            visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=0.8)
            out = visualizer.draw_instance_predictions(filtered_instances.to("cpu"))
            tt = time.time() - st
            print(tt)
            result_image = cv2.cvtColor(out.get_image(), cv2.COLOR_BGR2RGB)
            
            output_path = os.path.join(output_folder, f"result_{file_name}")
            cv2.imwrite(output_path, result_image)
            print(f"Saved result to {output_path}")

# Paths to your config file and trained model
config_path = PARENT_FOLDER + "/config.yaml"
model_weights_path = PARENT_FOLDER + "/model_final.pth"
input_folder = "../task18/training_data/v2/valid"  # Folder containing input images
output_folder = "output"  # Folder to save output images

# Set up the model for inference
cfg = setup_inference(config_path, model_weights_path)
predictor = DefaultPredictor(cfg)

# Set metadata
set_metadata()
metadata = MetadataCatalog.get("face_accessories")

# Process images in the input folder
process_images_in_folder(input_folder, output_folder, predictor, metadata)
# Out:
# c:\Users\roger\anaconda3\envs\detectron2\lib\site-packages\fvcore\common\checkpoint.py:252: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=torch.device("cpu"))
# 0.31787729263305664
# Saved result to output\result_00797.jpg
# 0.09053802490234375
# Saved result to output\result_00076.jpg
# 0.10362792015075684
# Saved result to output\result_11734.jpg
# 0.0975489616394043
# Saved result to output\result_00896.jpg
# 0.09381246566772461
# Saved result to output\result_00589.jpg
# 0.08909773826599121
# Saved result to output\result_00658.jpg
# 0.09388399124145508
# Saved result to output\result_11577.jpg
# 0.08219099044799805
# Saved result to output\result_10614.jpg
# 0.08234786987304688
# Saved result to output\result_10908.jpg
# 0.0957648754119873
# Saved result to output\result_00611.jpg
# 0.09603500366210938
# Saved result to output\result_00313.jpg
# 0.09608793258666992
# Saved result to output\result_00268.jpg
# 0.08817195892333984
# Saved result to output\result_00778.jpg
# 0.0809319019317627
# Saved result to output\result_00992.jpg
# 0.09678006172180176
# Saved result to output\result_00242.jpg
# 0.23271799087524414
# Saved result to output\result_10793.jpg
# 0.07518887519836426
# Saved result to output\result_00383.jpg
# 0.07813024520874023
# Saved result to output\result_11070.jpg
# 0.07813906669616699
# Saved result to output\result_10953.jpg
# 0.10248851776123047
# Saved result to output\result_11747.jpg
# 0.09424972534179688
# Saved result to output\result_10886.jpg
# 0.08530926704406738
# Saved result to output\result_00120.jpg
# 0.08556151390075684
# Saved result to output\result_00366.jpg
# 0.10218334197998047
# Saved result to output\result_11027.jpg
# 0.09430265426635742
# Saved result to output\result_00685.jpg
# 0.08738327026367188
# Saved result to output\result_00147.jpg
# 0.084930419921875
# Saved result to output\result_10970.jpg
# 0.09935808181762695
# Saved result to output\result_10888.jpg
# 0.09450101852416992
# Saved result to output\result_00446.jpg
# 0.07417702674865723
# Saved result to output\result_00168.jpg
# 0.09000468254089355
# Saved result to output\result_00191.jpg
# 0.09258151054382324
# Saved result to output\result_00901.jpg
# 0.0934896469116211
# Saved result to output\result_00200.jpg
# 0.08685922622680664
# Saved result to output\result_00597.jpg
# 0.09903478622436523
# Saved result to output\result_00620.jpg
# 0.08671140670776367
# Saved result to output\result_00672.jpg
# 0.08790183067321777
# Saved result to output\result_10547.jpg
# 0.08658170700073242
# Saved result to output\result_00569.jpg
# 0.09764742851257324
# Saved result to output\result_10530.jpg
# 0.10136961936950684
# Saved result to output\result_00126.jpg
# 0.07773447036743164
# Saved result to output\result_00802.jpg
# 0.0801079273223877
# Saved result to output\result_11440.jpg
# 0.08443760871887207
# Saved result to output\result_10680.jpg
# 0.10529136657714844
# Saved result to output\result_10316.jpg
# 0.09034991264343262
# Saved result to output\result_00646.jpg
# 0.10326266288757324
# Saved result to output\result_00988.jpg
# 0.08693909645080566
# Saved result to output\result_11447.jpg
# 0.10860776901245117
# Saved result to output\result_00455.jpg
# 0.08744096755981445
# Saved result to output\result_00968.jpg
# 0.10686326026916504
# Saved result to output\result_11632.jpg
# 0.08441925048828125
# Saved result to output\result_11313.jpg
# 0.09701728820800781
# Saved result to output\result_11935.jpg
# 0.08350253105163574
# Saved result to output\result_00920.jpg
# 0.09903836250305176
# Saved result to output\result_00452.jpg
# 0.10078835487365723
# Saved result to output\result_00334.jpg
# 0.10374927520751953
# Saved result to output\result_11718.jpg
# 0.07871127128601074
# Saved result to output\result_00927.jpg
# 0.08226704597473145
# Saved result to output\result_00926.jpg
# 0.09734177589416504
# Saved result to output\result_00429.jpg
# 0.09328246116638184
# Saved result to output\result_00851.jpg
# 0.10137701034545898
# Saved result to output\result_00192.jpg
# 0.09928202629089355
# Saved result to output\result_11307.jpg
# 0.10264253616333008
# Saved result to output\result_00292.jpg
# 0.09503436088562012
# Saved result to output\result_00945.jpg
# 0.0983123779296875
# Saved result to output\result_11823.jpg
# 0.1024177074432373
# Saved result to output\result_11910.jpg
# 0.10531973838806152
# Saved result to output\result_11160.jpg
# 0.10906386375427246
# Saved result to output\result_00148.jpg
# 0.10219836235046387
# Saved result to output\result_00980.jpg
# 0.10217642784118652
# Saved result to output\result_00342.jpg
# 0.09774923324584961
# Saved result to output\result_11423.jpg
# 0.09563136100769043
# Saved result to output\result_00001.jpg
# 0.09628605842590332
# Saved result to output\result_00635.jpg
# 0.08456039428710938
# Saved result to output\result_10766.jpg
# 0.09407520294189453
# Saved result to output\result_00958.jpg
# 0.08189821243286133
# Saved result to output\result_11254.jpg
# 0.08558130264282227
# Saved result to output\result_10122.jpg
# 0.09580564498901367
# Saved result to output\result_11497.jpg
# 0.09670519828796387
# Saved result to output\result_11930.jpg
# 0.10161447525024414
# Saved result to output\result_11922.jpg
# 0.08741092681884766
# Saved result to output\result_00122.jpg
# 0.10517287254333496
# Saved result to output\result_00704.jpg
# 0.08426046371459961
# Saved result to output\result_11650.jpg
# 0.08691835403442383
# Saved result to output\result_00445.jpg
# 0.08297157287597656
# Saved result to output\result_10321.jpg
# 0.10523343086242676
# Saved result to output\result_00112.jpg
# 0.10127639770507812
# Saved result to output\result_00449.jpg
# 0.11467123031616211
# Saved result to output\result_10342.jpg
# 0.10096001625061035
# Saved result to output\result_00333.jpg
# 0.11158323287963867
# Saved result to output\result_11233.jpg
# 0.09375548362731934
# Saved result to output\result_11871.jpg
# 0.11307358741760254
# Saved result to output\result_00910.jpg
# 0.33520030975341797
# Saved result to output\result_00398.jpg
# 0.0998373031616211
# Saved result to output\result_11069.jpg
# 0.10095429420471191
# Saved result to output\result_11427.jpg
# 0.09178614616394043
# Saved result to output\result_11929.jpg
# 0.10082006454467773
# Saved result to output\result_11824.jpg
# 0.09189915657043457
# Saved result to output\result_00863.jpg
# 0.10822010040283203
# Saved result to output\result_00808.jpg
# 0.08487701416015625
# Saved result to output\result_10610.jpg
# 0.09101557731628418
# Saved result to output\result_00291.jpg
# 0.08603835105895996
# Saved result to output\result_10629.jpg
# 0.10611963272094727
# Saved result to output\result_10336.jpg
# 0.07943367958068848
# Saved result to output\result_00979.jpg
# 0.08792924880981445
# Saved result to output\result_10001.jpg
# 0.0916287899017334
# Saved result to output\result_00748.jpg
# 0.10287857055664062
# Saved result to output\result_00539.jpg
# 0.08851218223571777
# Saved result to output\result_10065.jpg
# 0.09938621520996094
# Saved result to output\result_10106.jpg
# 0.09658598899841309
# Saved result to output\result_10428.jpg
# 0.10411357879638672
# Saved result to output\result_00605.jpg
# 0.09998774528503418
# Saved result to output\result_00486.jpg
# 0.08287334442138672
# Saved result to output\result_10550.jpg
# 0.0952908992767334
# Saved result to output\result_11358.jpg
# 0.09977293014526367
# Saved result to output\result_10821.jpg
# 0.09879231452941895
# Saved result to output\result_00969.jpg
# 0.09608888626098633
# Saved result to output\result_00717.jpg
# 0.08253836631774902
# Saved result to output\result_10465.jpg
# 0.08819746971130371
# Saved result to output\result_10998.jpg
# 0.08312869071960449
# Saved result to output\result_11675.jpg
# 0.09726977348327637
# Saved result to output\result_00641.jpg
# 0.08335685729980469
# Saved result to output\result_11841.jpg
# 0.09009361267089844
# Saved result to output\result_10267.jpg
# 0.08318114280700684
# Saved result to output\result_11674.jpg
# 0.0832056999206543
# Saved result to output\result_10862.jpg
# 0.08046412467956543
# Saved result to output\result_11439.jpg
# 0.10422563552856445
# Saved result to output\result_11665.jpg
# 0.09954071044921875
# Saved result to output\result_11807.jpg
# 0.08313679695129395
# Saved result to output\result_11920.jpg
# 0.08043789863586426
# Saved result to output\result_00350.jpg
# 0.08388853073120117
# Saved result to output\result_00374.jpg
# 0.10369348526000977
# Saved result to output\result_00030.jpg
# 0.1060793399810791
# Saved result to output\result_00618.jpg
# 0.09978079795837402
# Saved result to output\result_00068.jpg
# 0.10014986991882324
# Saved result to output\result_00846.jpg
# 0.08199262619018555
# Saved result to output\result_10955.jpg
# 0.10386943817138672
# Saved result to output\result_10020.jpg
# 0.08491754531860352
# Saved result to output\result_00795.jpg
# 0.10323429107666016
# Saved result to output\result_10948.jpg
# 0.08321833610534668
# Saved result to output\result_00911.jpg
# 0.08649778366088867
# Saved result to output\result_11697.jpg
# 0.08329367637634277
# Saved result to output\result_00912.jpg
# 0.08798003196716309
# Saved result to output\result_11213.jpg
# 0.09765958786010742
# Saved result to output\result_00857.jpg
# 0.104034423828125
# Saved result to output\result_00621.jpg
# 0.08388161659240723
# Saved result to output\result_00507.jpg
# 0.08306884765625
# Saved result to output\result_00081.jpg
# 0.0807347297668457
# Saved result to output\result_00032.jpg
# 0.08362817764282227
# Saved result to output\result_10999.jpg
# 0.08715438842773438
# Saved result to output\result_00388.jpg
# 0.10585594177246094
# Saved result to output\result_10307.jpg
# 0.08321404457092285
# Saved result to output\result_00118.jpg
# 0.08566117286682129
# Saved result to output\result_00438.jpg
# 0.1027982234954834
# Saved result to output\result_00899.jpg
# 0.09862375259399414
# Saved result to output\result_11838.jpg
# 0.08585834503173828
# Saved result to output\result_10564.jpg
# 0.09283447265625
# Saved result to output\result_10986.jpg
# 0.0807349681854248
# Saved result to output\result_00412.jpg
# 0.08918046951293945
# Saved result to output\result_10869.jpg
# 0.09244394302368164
# Saved result to output\result_00418.jpg
# 0.0816197395324707
# Saved result to output\result_00977.jpg
# 0.0844571590423584
# Saved result to output\result_00644.jpg
# 0.10150551795959473
# Saved result to output\result_00356.jpg
# 0.09818744659423828
# Saved result to output\result_00025.jpg
# 0.09993934631347656
# Saved result to output\result_00887.jpg
# 0.30117082595825195
# Saved result to output\result_11187.jpg
# 0.10705351829528809
# Saved result to output\result_00465.jpg
# 0.10133910179138184
# Saved result to output\result_00546.jpg
# 0.10016059875488281
# Saved result to output\result_00830.jpg
# 0.0833580493927002
# Saved result to output\result_00603.jpg
# 0.09273600578308105
# Saved result to output\result_00285.jpg
# 0.1000678539276123
# Saved result to output\result_11328.jpg
# 0.09725522994995117
# Saved result to output\result_11951.jpg
# 0.10196757316589355
# Saved result to output\result_00008.jpg
# 0.08964014053344727
# Saved result to output\result_00667.jpg
# 0.10557746887207031
# Saved result to output\result_00558.jpg
# 0.08946061134338379
# Saved result to output\result_00848.jpg
# 0.10213088989257812
# Saved result to output\result_10858.jpg
# 0.08813357353210449
# Saved result to output\result_11677.jpg
# 0.08233332633972168
# Saved result to output\result_00656.jpg
# 0.08075451850891113
# Saved result to output\result_00179.jpg
# 0.09385204315185547
# Saved result to output\result_00805.jpg
# 0.08227181434631348
# Saved result to output\result_10311.jpg
# 0.0873875617980957
# Saved result to output\result_10304.jpg
# 0.08563113212585449
# Saved result to output\result_00564.jpg
# 0.0883035659790039
# Saved result to output\result_11135.jpg
# 0.08313965797424316
# Saved result to output\result_11033.jpg
# 0.09909677505493164
# Saved result to output\result_00372.jpg
# 0.09828472137451172
# Saved result to output\result_10068.jpg
# 0.09210395812988281
# Saved result to output\result_10103.jpg
# 0.08080720901489258
# Saved result to output\result_00468.jpg
# 0.10495734214782715
# Saved result to output\result_00156.jpg
# 0.08652424812316895
# Saved result to output\result_10443.jpg
# 0.10171222686767578
# Saved result to output\result_10254.jpg
# 0.0844569206237793
# Saved result to output\result_11828.jpg
# 0.08368134498596191
# Saved result to output\result_00616.jpg
# 0.0848686695098877
# Saved result to output\result_10733.jpg
# 0.0884089469909668
# Saved result to output\result_00190.jpg
# 0.09780168533325195
# Saved result to output\result_00964.jpg
# 0.10338783264160156
# Saved result to output\result_00626.jpg
# 0.09912586212158203
# Saved result to output\result_11250.jpg
# 0.07772111892700195
# Saved result to output\result_00212.jpg
# 0.08045244216918945
# Saved result to output\result_11214.jpg
# 0.09979104995727539
# Saved result to output\result_11032.jpg
# 0.08464550971984863
# Saved result to output\result_10232.jpg
# 0.10114741325378418
# Saved result to output\result_10497.jpg
# 0.08511614799499512
# Saved result to output\result_10370.jpg
# 0.07962775230407715
# Saved result to output\result_11275.jpg
# 0.09812736511230469
# Saved result to output\result_10743.jpg
# 0.10017275810241699
# Saved result to output\result_11173.jpg
# 0.09685969352722168
# Saved result to output\result_00873.jpg
# 0.09350204467773438
# Saved result to output\result_00860.jpg
# 0.09795784950256348
# Saved result to output\result_11710.jpg
# 0.0900411605834961
# Saved result to output\result_11750.jpg
# 0.08726978302001953
# Saved result to output\result_10984.jpg
# 0.09683895111083984
# Saved result to output\result_10440.jpg
# 0.07580351829528809
# Saved result to output\result_00316.jpg
# 0.09411501884460449
# Saved result to output\result_11634.jpg
# 0.09734082221984863
# Saved result to output\result_00227.jpg
# 0.08645510673522949
# Saved result to output\result_00299.jpg
# 0.08636903762817383
# Saved result to output\result_00588.jpg
# 0.0844123363494873
# Saved result to output\result_10991.jpg
# 0.09791159629821777
# Saved result to output\result_00684.jpg
# 0.0991826057434082
# Saved result to output\result_10944.jpg
# 0.08069658279418945
# Saved result to output\result_10366.jpg
# 0.10213375091552734
# Saved result to output\result_10887.jpg
# 0.08687472343444824
# Saved result to output\result_00129.jpg
# 0.08660507202148438
# Saved result to output\result_10161.jpg
# 0.08591127395629883
# Saved result to output\result_10742.jpg
# 0.08908820152282715
# Saved result to output\result_11081.jpg
# 0.08312392234802246
# Saved result to output\result_00852.jpg
# 0.09453868865966797
# Saved result to output\result_10819.jpg
# 0.08353042602539062
# Saved result to output\result_00606.jpg
# 0.10666775703430176
# Saved result to output\result_11190.jpg
# 0.08668780326843262
# Saved result to output\result_11062.jpg
# 0.09804892539978027
# Saved result to output\result_11701.jpg
# 0.09952616691589355
# Saved result to output\result_11345.jpg
# 0.09967041015625
# Saved result to output\result_10931.jpg
# 0.08757758140563965
# Saved result to output\result_10196.jpg
# 0.1001739501953125
# Saved result to output\result_11088.jpg
# 0.07906913757324219
# Saved result to output\result_00271.jpg
# 0.08200335502624512
# Saved result to output\result_00890.jpg
# 0.28230786323547363
# Saved result to output\result_10011.jpg
# 0.09550070762634277
# Saved result to output\result_10622.jpg
# 0.09033846855163574
# Saved result to output\result_11721.jpg
# 0.0828094482421875
# Saved result to output\result_00508.jpg
# 0.08581852912902832
# Saved result to output\result_11862.jpg
# 0.07377219200134277
# Saved result to output\result_10523.jpg
# 0.08441710472106934
# Saved result to output\result_10681.jpg
# 0.07732772827148438
# Saved result to output\result_00290.jpg
# 0.08056402206420898
# Saved result to output\result_11035.jpg
# 0.08174276351928711
# Saved result to output\result_11751.jpg
# 0.09857821464538574
# Saved result to output\result_11281.jpg
# 0.0831918716430664
# Saved result to output\result_00885.jpg
# 0.08939218521118164
# Saved result to output\result_10987.jpg
# 0.09829068183898926
# Saved result to output\result_10707.jpg
# 0.09486579895019531
# Saved result to output\result_10422.jpg
# 0.08183145523071289
# Saved result to output\result_00900.jpg
# 0.08765697479248047
# Saved result to output\result_00991.jpg
# 0.0857996940612793
# Saved result to output\result_11024.jpg
# 0.09952735900878906
# Saved result to output\result_10780.jpg
# 0.07739758491516113
# Saved result to output\result_00742.jpg
# 0.1000514030456543
# Saved result to output\result_00882.jpg
# 0.09621310234069824
# Saved result to output\result_11435.jpg
# 0.0982973575592041
# Saved result to output\result_10837.jpg
# 0.09948849678039551
# Saved result to output\result_00919.jpg
# 0.08761262893676758
# Saved result to output\result_10455.jpg
# 0.09995508193969727
# Saved result to output\result_00510.jpg
# 0.10276603698730469
# Saved result to output\result_00664.jpg
# 0.08325767517089844
# Saved result to output\result_00609.jpg
# 0.08425164222717285
# Saved result to output\result_00855.jpg
# 0.09538602828979492
# Saved result to output\result_00239.jpg
# 0.08223176002502441
# Saved result to output\result_10894.jpg
# 0.08715105056762695
# Saved result to output\result_11134.jpg
# 0.07926607131958008
# Saved result to output\result_10581.jpg
# 0.08384346961975098
# Saved result to output\result_00738.jpg
# 0.08643364906311035
# Saved result to output\result_00417.jpg
# 0.08303213119506836
# Saved result to output\result_00741.jpg
# 0.08183431625366211
# Saved result to output\result_00990.jpg
# 0.09211421012878418
# Saved result to output\result_11242.jpg
# 0.08761119842529297
# Saved result to output\result_11912.jpg
# 0.07408618927001953
# Saved result to output\result_11227.jpg
# 0.08768725395202637
# Saved result to output\result_10023.jpg
# 0.08238554000854492
# Saved result to output\result_10971.jpg
# 0.08554315567016602
# Saved result to output\result_10920.jpg
# 0.08599090576171875
# Saved result to output\result_10648.jpg
# 0.1041562557220459
# Saved result to output\result_00266.jpg
# 0.08877038955688477
# Saved result to output\result_10597.jpg
# 0.08826231956481934
# Saved result to output\result_00177.jpg
# 0.09991455078125
# Saved result to output\result_00414.jpg
# 0.09141659736633301
# Saved result to output\result_10885.jpg
# 0.0795600414276123
# Saved result to output\result_11230.jpg
# 0.08826708793640137
# Saved result to output\result_10437.jpg
# 0.07236313819885254
# Saved result to output\result_10800.jpg
# 0.08338451385498047
# Saved result to output\result_00344.jpg
# 0.08169674873352051
# Saved result to output\result_00401.jpg
# 0.087615966796875
# Saved result to output\result_11659.jpg
# 0.08473372459411621
# Saved result to output\result_00252.jpg
# 0.10182976722717285
# Saved result to output\result_10739.jpg
# 0.07352066040039062
# Saved result to output\result_00352.jpg
# 0.08554697036743164
# Saved result to output\result_00806.jpg
# 0.08256268501281738
# Saved result to output\result_00619.jpg
# 0.08749127388000488
# Saved result to output\result_00015.jpg
# 0.0859534740447998
# Saved result to output\result_11891.jpg
# 0.08325409889221191
# Saved result to output\result_10899.jpg
# 0.09749531745910645
# Saved result to output\result_00936.jpg
# 0.10321378707885742
# Saved result to output\result_10880.jpg
# 0.10571432113647461
# Saved result to output\result_11007.jpg
# 0.09943723678588867
# Saved result to output\result_11224.jpg
# 0.08333039283752441
# Saved result to output\result_00363.jpg
# 0.08810758590698242
# Saved result to output\result_11001.jpg
# 0.08472537994384766
# Saved result to output\result_10093.jpg
# 0.08844804763793945
# Saved result to output\result_10584.jpg
# 0.08516931533813477
# Saved result to output\result_00086.jpg
# 0.09052157402038574
# Saved result to output\result_00427.jpg
# 0.08327269554138184
# Saved result to output\result_00381.jpg
# 0.08787250518798828
# Saved result to output\result_11067.jpg
# 0.0856621265411377
# Saved result to output\result_10378.jpg
# 0.29990386962890625
# Saved result to output\result_00188.jpg
# 0.07903933525085449
# Saved result to output\result_00272.jpg
# 0.09285783767700195
# Saved result to output\result_00753.jpg
# 0.08377194404602051
# Saved result to output\result_10369.jpg
# 0.08548164367675781
# Saved result to output\result_00528.jpg
# 0.08545827865600586
# Saved result to output\result_10608.jpg
# 0.09747934341430664
# Saved result to output\result_11066.jpg
# 0.09710955619812012
# Saved result to output\result_11247.jpg
# 0.09674978256225586
# Saved result to output\result_11897.jpg
# 0.08295559883117676
# Saved result to output\result_00540.jpg
# 0.1025094985961914
# Saved result to output\result_10209.jpg
# 0.09982824325561523
# Saved result to output\result_00476.jpg
# 0.09109234809875488
# Saved result to output\result_10975.jpg
# 0.09990572929382324
# Saved result to output\result_10483.jpg
# 0.10249662399291992
# Saved result to output\result_10589.jpg
# 0.0867457389831543
# Saved result to output\result_00391.jpg
# 0.09964799880981445
# Saved result to output\result_11482.jpg
# 0.11146044731140137
# Saved result to output\result_00160.jpg
# 0.09905767440795898
# Saved result to output\result_10363.jpg
# 0.0989835262298584
# Saved result to output\result_00370.jpg
# 0.08991765975952148
# Saved result to output\result_00047.jpg
# 0.08374762535095215
# Saved result to output\result_00982.jpg
# 0.09459066390991211
# Saved result to output\result_00302.jpg
# 0.08232903480529785
# Saved result to output\result_11607.jpg
# 0.10254406929016113
# Saved result to output\result_00172.jpg
# 0.08938241004943848
# Saved result to output\result_11222.jpg
# 0.07842063903808594
# Saved result to output\result_00610.jpg
# 0.09235477447509766
# Saved result to output\result_00594.jpg
# 0.08797860145568848
# Saved result to output\result_10213.jpg
# 0.08391046524047852
# Saved result to output\result_10099.jpg
# 0.08315658569335938
# Saved result to output\result_00841.jpg
# 0.0821993350982666
# Saved result to output\result_00499.jpg
# 0.09446430206298828
# Saved result to output\result_00884.jpg
# 0.08315658569335938
# Saved result to output\result_10810.jpg
# 0.0906362533569336
# Saved result to output\result_00694.jpg
# 0.08958005905151367
# Saved result to output\result_00055.jpg
# 0.0848081111907959
# Saved result to output\result_10486.jpg
# 0.0778951644897461
# Saved result to output\result_11583.jpg
# 0.08818817138671875
# Saved result to output\result_10368.jpg
# 0.08654451370239258
# Saved result to output\result_00889.jpg
# 0.08799195289611816
# Saved result to output\result_11485.jpg
# 0.09408140182495117
# Saved result to output\result_11093.jpg
# 0.08739185333251953
# Saved result to output\result_00369.jpg
# 0.08527135848999023
# Saved result to output\result_10638.jpg
# 0.10491824150085449
# Saved result to output\result_10678.jpg
# 0.08822011947631836
# Saved result to output\result_00897.jpg
# 0.10579252243041992
# Saved result to output\result_11926.jpg
# 0.09239697456359863
# Saved result to output\result_10479.jpg
# 0.09807348251342773
# Saved result to output\result_00128.jpg
# 0.09297895431518555
# Saved result to output\result_10732.jpg
# 0.08585691452026367
# Saved result to output\result_11843.jpg
# 0.10448026657104492
# Saved result to output\result_00331.jpg
# 0.0818030834197998
# Saved result to output\result_11631.jpg
# 0.09921598434448242
# Saved result to output\result_00450.jpg
# 0.08869791030883789
# Saved result to output\result_10488.jpg
# 0.08320331573486328
# Saved result to output\result_10572.jpg
# 0.08905625343322754
# Saved result to output\result_00387.jpg
# 0.08406567573547363
# Saved result to output\result_00627.jpg
# 0.10347986221313477
# Saved result to output\result_00561.jpg
# 0.0916130542755127
# Saved result to output\result_00351.jpg
# 0.09685015678405762
# Saved result to output\result_00500.jpg
# 0.09668779373168945
# Saved result to output\result_00144.jpg
